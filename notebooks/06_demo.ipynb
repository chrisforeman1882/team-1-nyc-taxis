# %% [markdown]
# # 06 — Final Integrated Demo
#
# **Tickets:** DEMO-01, INT-01, INT-02
# **Purpose:** End-to-end walkthrough of the full Data & AI platform for stakeholders.
#
# ## Demo Narrative
#
# > *"We built a complete Data & AI platform that ingests raw taxi trip records, cleans and models them into business-ready tables, surfaces KPIs on a live dashboard, predicts trip fares using ML, and lets anyone ask natural-language questions about NYC taxi data and policy — all inside Databricks."
#
# ---
#
# ## Run Order
#
# | Step | Notebook | What it shows |
# |------|----------|---------------|
# | 1 | `01_ingest` | Raw data → Bronze Delta table |
# | 2 | `02_silver_cleaning` | Cleaning pipeline |
# | 3 | `02_silver_dq` | Data quality checks pass |
# | 4 | `03_gold_analytics` | KPIs computed |
# | 5 | `03_gold_dashboard` | Live dashboard |
# | 6 | `04_ml_training` | Model trained, logged in MLflow |
# | 7 | `05_rag` | Natural-language Q&A demo |
#
# ---

# %% [markdown]
# ## INT-01 — End-to-end integration check

# %%
# TODO: verify Bronze → Silver → Gold pipeline runs cleanly
# TODO: run data quality assertions; assert all pass
# TODO: load registered ML model and run a sample prediction
# TODO: run a RAG query and display the answer

# %% [markdown]
# ## Live demo cells
#
# <!-- Add polished, presentation-ready cells here during Day 4 polish -->
